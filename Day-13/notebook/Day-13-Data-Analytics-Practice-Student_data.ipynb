# %% [markdown]
# # Bài 1: Làm sạch dữ liệu học sinh

# %% [markdown]
# File dữ liệu `data/students_data.csv` chứa danh sách học sinh với các thông tin như:
#
# * Mã học sinh (`student_id`)
# * Tên (`name`)
# * Tuổi (`age`)
# * Giới tính (`gender`)
# * Lớp (`grade`)
# * Điểm từng môn (`math_score`, `english_score`, `science_score`)
# * Ngày nhập học (`enrolled_date`)
# * Nhận xét (`remarks`)
#
# Tuy nhiên, dữ liệu này có **nhiều vấn đề chất lượng**: thiếu dữ liệu, dữ liệu trùng, định dạng không đồng nhất, giá trị ngoại lai (outlier), v.v.
# Nhiệm vụ của bạn là **làm sạch và chuẩn hóa bộ dữ liệu** này để chuẩn bị cho bước phân tích tiếp theo.

# %% [markdown]
# ## Bước 1. Khám phá dữ liệu

# %%
import pandas as pd

# Đọc dữ liệu
df = pd.read_csv("./data/students_data.csv")

# %% [markdown]
# ## Bước 2. Xử lý dữ liệu thiếu (Missing Data)

# %% [markdown]
# ## Bước 3. Làm sạch dữ liệu dạng văn bản

# %% [markdown]
# Đồng nhất dữ liệu trong một Serie
#
# Ví dụ: Cột `gender` có nhiều cách viết: `"Male"`, `"male"`, `"MALE"`, `"FEMALE"`, `"female"`

# %% [markdown]
# ## Bước 4. Xử lý giá trị ngoại lai (Outliers)

# %% [markdown]
# ## Bước 5. Chuẩn hoá dữ liệu ngày tháng

# %% [markdown]
# Chuẩn hóa về cùng một định dạng `YYYY-MM-DD` bằng `pd.to_datetime()`.

# %% [markdown]
# ## Bước 6. Tạo cột mới và thống kê mô tả

# %% [markdown]
# * Tạo cột `average_score` = trung bình của 3 cột điểm.
# * Dùng `.describe()` để xem thống kê cơ bản.
# * Phân tích nhanh:
#
#   * Điểm trung bình môn nào cao nhất?
#   * Có bao nhiêu học sinh có điểm trung bình > 80?

# %% [markdown]
# ## Bước 7. Xuất dữ liệu sau khi làm sạch

# %% [markdown]
# * Lưu kết quả ra file mới:
#   👉 `students_data_cleaned.csv`
