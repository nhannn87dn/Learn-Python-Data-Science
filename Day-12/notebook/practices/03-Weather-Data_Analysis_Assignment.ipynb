# %% [markdown]
# ## 📘 Giải thích dữ liệu đầu vào
#
# File `data/weather_data.csv` gồm các cột:
#
# | Cột | Ý nghĩa |
# |-----|----------|
# | `Ozone` | Nồng độ ozone (ppb) |
# | `Solar.R` | Bức xạ mặt trời (Langley) |
# | `Wind` | Tốc độ gió (mph) |
# | `Temp C` | Nhiệt độ (°C) |
# | `Month` | Tháng ghi nhận |
# | `Day` | Ngày ghi nhận |
# | `Year` | Năm ghi nhận |
# | `Temp` | Nhiệt độ (°F) |
# | `Weather` | Loại thời tiết: `S` (Sunny), `C` (Cloudy), `PS` (Partly Sunny)`

# %% [markdown]
# ### 🧩 **Bài 1: Đọc dữ liệu**
# Đọc file `data/weather_data.csv` bằng Pandas và hiển thị 5 dòng đầu tiên.

# %%
#Code ở đây

# %% [markdown]
# ### ☁️ **Bài 2: Kiểm tra thông tin dữ liệu**
# Hiển thị thông tin tổng quan về DataFrame (kiểu dữ liệu, giá trị null, số dòng, số cột, ...).

# %% [markdown]
# ### 🌡️ **Bài 3: Thống kê mô tả dữ liệu**
# Tính giá trị trung bình, lớn nhất, nhỏ nhất của các cột `Ozone`, `Solar.R`, `Wind`, `Temp C`.

# %% [markdown]
# ### 🔍 **Bài 4: Lọc dữ liệu cơ bản**
# Lọc tất cả các ngày có nhiệt độ (°C) > 70 và tốc độ gió < 10 mph.

# %% [markdown]
# ### 🧮 **Bài 5: Lọc dữ liệu nâng cao bằng `query()`**
# Lọc các ngày trong tháng 5 (`Month == 5`) có thời tiết `Sunny` và `Ozone` > 30 bằng cú pháp `query()`.

# %% [markdown]
# ### 📅 **Bài 6: Lọc dữ liệu bằng `isin()` theo nhiều ngày**
# Lọc dữ liệu cho các ngày cụ thể `[1, 3, 5]` trong tháng 5.

# %% [markdown]
# ### ⚙️ **Bài 7: Xử lý dữ liệu thiếu**
# Kiểm tra và thay thế các giá trị thiếu (`NA`) trong `Ozone` và `Solar.R` bằng giá trị trung bình của từng cột.

# %% [markdown]
# ### 📊 **Bài 8: Nhóm dữ liệu theo thời tiết**
# Nhóm dữ liệu theo cột `Weather` và tính trung bình các cột `Ozone`, `Solar.R`, `Temp C`.

# %% [markdown]
# ### 📈 **Bài 9: Thống kê tổng hợp theo tháng**
# Nhóm dữ liệu theo `Month` và `Weather`, sau đó tính:
# - Trung bình `Temp C`
# - Tổng lượng `Ozone`

# %% [markdown]
# ### 🔢 **Bài 10: Sắp xếp dữ liệu**
# Sắp xếp dữ liệu theo:
# - Cột `Temp C` giảm dần
# - Nếu trùng `Temp C` thì theo `Ozone` tăng dần

# %% [markdown]
# ### 🧰 **Bài 11: Thêm cột mới**
# Thêm cột `Temp_F_to_C_Diff` thể hiện chênh lệch giữa `Temp` (°F) và `Temp C` (°C).

# %% [markdown]
# ### 🌞 **Bài 12: Tìm ngày nóng nhất và lạnh nhất**
# Xác định ngày có nhiệt độ cao nhất và thấp nhất (theo °C).
