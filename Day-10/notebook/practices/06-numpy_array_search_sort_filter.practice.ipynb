# %% [markdown]
# # Bài tập về: NumPy Searching, Sorting & Filtering Arrays

# %%
#Import thư viện
import numpy as np

# %% [markdown]
# **Bài 1**: Cho một mảng như sau:
# ```python
# arr = np.array([7, 12, 5, 8, 3, 10, 15, 6])
# ```
#
# Yêu cầu:
#
# - Tìm tất cả các vị trí (index) có số chẵn.
# - In ra các số chẵn đó từ mảng gốc.
#
# Kết quả mong đợi:
# - Vị trí số chẵn: `(array([1, 3, 5, 7]),)`
# - Các số chẵn: `[12  8 10  6]`

# %%
# bắt đầu code từ đây

# %% [markdown]
# **Bài 2**: Cho mảng như sau
# ```python
# arr = np.array([10, 20, 30, 50, 60, 70])   # mảng đã được sắp xếp
# ```
# Yêu cầu:
#
# - Tìm vị trí nên chèn các giá trị sau, sao cho mảng vẫn giữ thứ tự tăng dần: `values = [25, 55, 70, 5]`
# - In kết quả cho từng giá trị.
#
# Kết quả mong đợi:
# - 25 nên chèn ở vị trí: 2
# - 55 nên chèn ở vị trí: 4
# - 70 nên chèn ở vị trí: 6
# - 5  nên chèn ở vị trí: 0

# %%
arr = np.array([10, 20, 30, 50, 60, 70])   # mảng đã được sắp xếp
# bắt đầu code từ đây

# %% [markdown]
# **Bài 3** Cho mảng như sau:
#
# ```python
# arr = np.array([45, 12, 67, 33, 89, 21])
# ```
# Yêu cầu:
# - Tạo mảng mới đã sắp xếp tăng dần → đặt tên là sorted_arr
# - In cả mảng gốc và mảng đã sắp xếp
# - In thêm mảng sắp xếp giảm dần (dùng kỹ thuật slicing)
#
# Kết quả mong đợi:
# - Mảng gốc: [45 12 67 33 89 21]
# - Mảng tăng dần: [12 21 33 45 67 89]
# - Mảng giảm dần: [89 67 45 33 21 12]

# %%
arr = np.array([45, 12, 67, 33, 89, 21])
# bắt đầu code từ đây

# %% [markdown]
# **Bài 4** Cho mảng như sau:
#
# ```python
# nhiet_do = np.array([28, 35, 32, 38, 30, 29, 39])
# ```
#
# **Yêu cầu đầu ra**:
# 1. Các ngày **có nhiệt độ ≥ 35°C**: `[35 38 39]`
# 2. Các ngày **nhiệt độ từ 30 đến 35°C** (bao gồm cả 30 và 35): `[35 32 30]`
# 3. **Số ngày** có nhiệt độ ≥ 35°C: `3`

# %%
nhiet_do = np.array([28, 35, 32, 38, 30, 29, 39])
# Code từ đây

# %% [markdown]
# **Bài 5** Cho bảng điểm của 10 học sinh:
#
# ```python
# names = np.array(['An', 'Bình', 'Cường', 'Dương', 'Hà', 'Khánh', 'Lan', 'Minh', 'Ngọc', 'Phong'])
# scores = np.array([7.5, 8.0, 4.5, 9.0, 6.5, 8.5, 5.5, 9.5, 7.0, 8.8])
# ```
#  Yêu cầu thực hiện từng bước và in kết quả:
#  1. Tìm các vị trí học sinh có điểm >= 8.0 (dùng np.where)
#  2. In tên và điểm của các học sinh đó
#  3. Tạo mảng mới chỉ chứa điểm >= 8.0 (dùng filtering)
#  4. Sắp xếp mảng điểm >= 8.0 theo thứ tự giảm dần và in ra
#     kèm tên học sinh tương ứng (gợi ý: dùng argsort)
#
#  Kết quả mong đợi (phần cuối):
# - Học sinh điểm cao (>=8.0), sắp xếp giảm dần:
# - Minh    : 9.5
# - Dương   : 9.0
# - Ngọc    : 8.8
# - Khánh   : 8.5
# - Bình    : 8.0

# %%
names = np.array(['An', 'Bình', 'Cường', 'Dương', 'Hà', 'Khánh', 'Lan', 'Minh', 'Ngọc', 'Phong'])
scores = np.array([7.5, 8.0, 4.5, 9.0, 6.5, 8.5, 5.5, 9.5, 7.0, 8.8])
# Code từ đây
