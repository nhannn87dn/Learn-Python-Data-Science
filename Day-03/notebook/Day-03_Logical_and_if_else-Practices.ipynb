# %% [markdown]
# # Bài tập Day 03 - Câu lệnh điều khiển

# %% [markdown]
# **Câu 1:** Viết chương trình yêu cầu người dùng nhập một số nguyên và kiểm tra xem số đó có nằm trong khoảng từ 10 đến 20 không

# %% [markdown]
# **Câu 2:** Viết chương trình yêu cầu người dùng nhập điểm Toán, Lý, Hóa, Sinh của một sinh viên và kiểm tra xem sinh viên đó có lên lớp không. In ra: "Lên lớp: Nếu từ 5.0 trở lên và không có môn nào điểm dưới 3.0 còn ngược lại là "Không được lên lớp"

# %% [markdown]
# **Câu 3:** Viết chương trình yêu cầu người dùng nhập một số nguyên và kiểm tra xem số đó có chia hết cho cả 3 và 5 không. Nếu có in ra: "Chia hết cho 3 và 5", ngược lại "Không chia hết"

# %% [markdown]
# **Câu 4:** Viết chương trình yêu cầu người dùng nhập một số nguyên và kiểm tra xem số đó có nằm ngoài khoảng từ 1 đến 100 không và đồng thời không là số chia hết cho 5. Nếu thõa điều kiện thi in ra Đúng, còn lại là Sai.

# %% [markdown]
# **Câu 5:** Viết một chương trình Python để tính tiền thanh toán khi mua vé xem phim. Chương trình sẽ tính toán tổng chi phí dựa trên các yếu tố sau:
#
# Loại vé:
#
# - Vé trẻ em - **kid** có giá 70,000 VNĐ
# - Vé người lớn - **adult** có giá 100,000 VNĐ
# - Vé người cao tuổi - **older** có giá 80,000 VNĐ
#
# Số lượng vé. Chiết khấu đặc biệt:
#
# - Nếu mua từ 5 vé trở lên, giảm 10% tổng giá trị đơn hàng.
# - Nếu mua từ 10 vé trở lên, giảm 20% tổng giá trị đơn hàng.
#
# Chương trình sẽ nhập vào thông tin của 2 khách hàng, bao gồm loại vé và số lượng vé, sau đó tính và in ra số tiền mà mỗi khách hàng phải thanh toán sau khi áp dụng chiết khấu

# %% [markdown]
# **Câu 6:** Viết chương trình yêu cầu người dùng nhập vào số kilomet quảng đường giao hàng.
#
# - Nếu quảng đường < 5km thì phí giao hàng là 10.000đ
# - Nếu quảng đường >= 5km thì phí giao hàng là  35.000đ
# - Nếu quảng đường > 10km thì phí giao hàng là 50.000đ
#
# Yêu cầu tính và in ra phí giao hàng dựa vào số kilomet giao hàng.

# %% [markdown]
# **Câu 7:** Viết chương trình yêu cầu người dùng nhập ba số và in ra số lớn nhất trong ba số đó.

# %% [markdown]
# **Câu 8:** Viết chương trình yêu cầu người dùng nhập một số nguyên và kiểm tra xem số đó có là số chia hết cho 3 và 5 đồng thời không là số chia hết cho 2 hay không. Nếu thõa điều kiện thì in ra: Đúng, ngược lại là Sai.

# %% [markdown]
# **Câu 9:** Mẹ của Nam bán Chôm Chôm. Giá 1kg là 25.000đ
#
# - Nếu mua > 3kg thì giá chỉ còn 22.000kg /1 kg
# - Nếu mua > 5kg thì giá chỉ còn 18.000kg /1 kg
#
# Với vai trò là lập trình viên, hãy tạo một chương trình tính toán nhận vào số kg nhập từ người dùng. Tính và in ra số tiền khách hàng phải trả khi mua số kg tương ứng.

# %% [markdown]
# **Câu 10:** Gia đình Tony chuẩn bị đi du lịch Phú Quốc.Được biết:
#
# -  Phòng hạng A, đơn giá 500USD / 1 ngày
# -  Phòng hạng B, đơn giá 300USD / 1 ngày
# -  Phòng hạng C, đơn giá 150USD / 1 ngày
#
# Và Nếu ở từ 3 ngày trở lên thì được giảm 10%.
#
# Bạn hãy lập trình một công cụ để tính tổng chi phí chuyến đi của họ trong các trường hợp:
#
# - Đi 2 ngày và sử dụng 2 phòng hạng A
# - Đi 5 ngày và sử dụng 2 phòng hạng C
#
# Gợi ý: Dùng input() để nhận giá trị số ngày, và hạng phòng.

# %% [markdown]
# **Câu 11:** Viết một chương trình yêu cầu người dùng nhập mật khẩu.
# - Nếu mật khẩu đúng (ví dụ: "python123"), in ra thông báo "Mật khẩu đúng, truy cập thành công."
# - Nếu mật khẩu sai, in ra thông báo "Mật khẩu sai, vui lòng thử lại."

# %% [markdown]
# **Câu 12:** Viết một chương trình Python để tính tiền thanh toán cho khách hàng dựa vào xếp hạng thành viên và giá trị đơn hàng. Có ba hạng thành viên: "Gold", "Silver", và "Bronze". Tùy theo hạng thành viên, khách hàng sẽ nhận được mức giảm giá khác nhau:
#
# - Nếu là hạng Gold và đơn hàng >= 5000USD : Giảm 20%
# - Nếu là hạng Silver và đơn hàng >= 5000USD: Giảm 15%
# - Nếu là hạng  Bronze và đơn hàng >= 5000USD: Giảm 10%
#
# Chương trình sẽ nhập vào thông tin của 2 khách hàng, bao gồm hạng thành viên và giá trị đơn hàng, sau đó tính và in ra số tiền mà mỗi khách hàng phải thanh toán sau khi áp dụng giảm giá

# %% [markdown]
# **Câu 13:** Tính chiết khấu đơn hàng
#
# **Yêu cầu:**
# Nhập tổng giá trị đơn hàng (VND).
#
# * Nếu ≥ 10 triệu: giảm 10%
# * Nếu từ 5–9.999 triệu: giảm 5%
# * Dưới 5 triệu: không giảm
#   In ra **số tiền sau khi giảm**.
#
# **Ví dụ:**
#
# ```
# Nhập tổng đơn hàng: 12000000
# → Giảm 10%, số tiền phải trả: 10.800.000 VND
# ```

# %% [markdown]
# **Câu 14**  Xác định thuế nhập khẩu theo loại hàng
#
# **Yêu cầu:**
# Nhập tên loại hàng (vd: “máy móc”, “thực phẩm”, “quần áo”).
# Tính thuế suất tương ứng:
#
# * máy móc: 5%
# * thực phẩm: 10%
# * quần áo: 12%
#   Nếu nhập loại khác → báo “Không xác định loại hàng”.
#
# **Gợi ý:** dùng `.lower()` để tránh phân biệt hoa thường.

# %% [markdown]
# **Câu 15** Tính phí vận chuyển quốc tế
#
# **Yêu cầu:**
# Nhập trọng lượng (kg) và khu vực:
#
# * “A” (Đông Nam Á): 5 USD/kg
# * “B” (Châu Á khác): 7 USD/kg
# * “C” (Châu Âu/Mỹ): 10 USD/kg
#   Nếu trọng lượng > 50kg → giảm 10% tổng phí.

# %% [markdown]
# **Câu 16** Tính hoa hồng nhân viên kinh doanh
#
# **Yêu cầu:**
# Nhập doanh số bán hàng (triệu VND).
#
# * ≥ 100: thưởng 10%
# * 50–99: thưởng 5%
# * < 50: không thưởng
#   In ra **tiền hoa hồng**.

# %% [markdown]
# **Câu 17:** Tính thuế thu nhập cá nhân
#
# **Yêu cầu:**
# Nhập thu nhập (triệu VND/tháng).
#
# * ≤ 10: miễn thuế
# * 10–20: thuế 10%
# * 20–40: thuế 15%
# * \> 40: thuế 20%
# > In ra **số thuế phải nộp**.

# %% [markdown]
# **Câu 18**: Đánh giá kết quả kinh doanh
#
# **Yêu cầu:**
# Nhập **doanh thu** và **chi phí**.
# Tính lợi nhuận = doanh thu – chi phí.
#
# * Nếu lợi nhuận > 0 → “Lãi”
# * = 0 → “Hòa vốn”
# * < 0 → “Lỗ”
# > In ra kết quả kinh doanh

# %% [markdown]
# **Câu 19:** Kiểm tra đủ điều kiện ưu đãi xuất khẩu
#
# **Yêu cầu:**
# Viết chương trình yêu cầu Người dùng khai báo nước xuất khẩu và trị gia lô hàng xuất khẩu
#
# Một lô hàng được ưu đãi nếu:
#
# * Nước xuất khẩu là “Vietnam”
# * Và giá trị ≥ 10.000 USD
#
# Nếu đủ cả hai thì in ra → “Được ưu đãi thuế xuất khẩu”, ngược lại “Không đủ điều kiện”.

# %% [markdown]
# **Câu 20** Tính tổng chi phí nhập khẩu một lô hàng
#
# 🎯 **Yêu cầu bài toán**
#
# Công ty nhập khẩu cần tính **tổng chi phí nhập khẩu (Tổng phí phải trả)** cho từng lô hàng.
# Chi phí gồm các phần sau:
#
# | Thành phần                 | Cách tính                                                                                   |
# | -------------------------- | ------------------------------------------------------------------------------------------- |
# | **Giá trị hàng hóa (USD)** | do người dùng nhập                                                                          |
# | **Thuế nhập khẩu**         | tùy theo loại hàng: <br>• `machinery`: 5%<br>• `food`: 10%<br>• `clothing`: 12%             |
# | **Phí vận chuyển quốc tế** | dựa trên khu vực: <br>• `Asia`: 5 USD/kg<br>• `Europe`: 10 USD/kg<br>• `America`: 12 USD/kg |
# | **Giảm giá (discount)**    | nếu tổng giá trị hàng (USD) > 50,000 **và** khu vực là `Asia` → giảm 5% tổng chi phí        |
# | **Tỷ giá quy đổi**         | 1 USD = 24,500 VND                                                                          |
#
# ---
#
# 🧮 **Công thức tổng chi phí**
#
# ```
# Tổng phí (VND) = (Giá trị hàng + Thuế nhập khẩu + Phí vận chuyển - Giảm giá) × 24,500
# ```
#
# ---
#
# 🧑‍💻 **Yêu cầu cụ thể**
#
# Viết chương trình Python:
#
# 1. Nhập:
#
#    * Giá trị hàng hóa (USD)
#    * Trọng lượng (kg)
#    * Khu vực (`Asia`, `Europe`, `America`)
#    * Loại hàng (`machinery`, `food`, `clothing`)
# 2. Tính thuế, phí, giảm giá (nếu có)
# 3. In ra **bảng tóm tắt kết quả** như sau:
#
# ```
# === KẾT QUẢ TÍNH CHI PHÍ NHẬP KHẨU ===
# Giá trị hàng hóa: 60,000 USD
# Thuế nhập khẩu: 6.000 USD
# Phí vận chuyển: 500 USD
# Giảm giá: 3,275 USD
# Tổng phí sau giảm: 63,225 USD
# => Tổng tiền phải trả: 1,548,012,500 VND
# ```

# %% [markdown]
# ========================================
#
# CHỨC MỪNG ! BẠN ĐÃ VƯỢT QUA THỬ THÁCH BÀI TẬP !
#
# ## Cách nộp bài
#
# 1. Click vào liên kết **Share** phía góc trên bên phải
# 1. Tại dòng **General access**, đổi từ **Restricted** thành **Anyone with the link**
# 1. Click vào nút **Copy Link**, lấy link đó gửi cho giáo viên.
