# %% [markdown]
# # Bài tập thực hành - Sử dụng Matplotlib

# %% [markdown]
# Mục tiêu nắm được các phương thức triển khai trực quan hoá dữ liệu với các biểu đồ phổ biến trong Matplotlib

# %%
#Import thư viện
import matplotlib.pyplot as plt

# %% [markdown]
# ## **1. Doanh thu theo tháng**
#
# Dữ liệu:
#
# * Tháng: Jan–Jun
# * Doanh thu (nghìn USD): [120, 150, 170, 160, 190, 210]
#
# **Yêu cầu:**
# Vẽ biểu đồ đường thể hiện xu hướng doanh thu 6 tháng đầu năm.

# %%
#code ở đây

# %% [markdown]
# ## **2. So sánh 2 tuyến vận chuyển**
#
# Số lượng container vận chuyển theo 6 tháng:
#
# * Tuyến Việt Nam → Singapore: [40, 50, 55, 52, 60, 68]
# * Tuyến Việt Nam → Thái Lan: [35, 42, 48, 50, 53, 55]
#
# **Yêu cầu:**
# Vẽ 2 line chart trên cùng 1 biểu đồ + legend phân biệt.

# %%
#code ở đây

# %% [markdown]
# ## **3.  Chi phí xăng dầu**
#
# Chi phí nhiên liệu (triệu VND):
#
# * Các quý: Q1–Q4
# * Cost: [320, 300, 350, 370]
#
# **Yêu cầu:**
# Vẽ line chart có:
#
# * Màu đỏ
# * Kiểu dashed "--"
# * Marker hình tròn

# %%
#Code ở đây

# %% [markdown]
# ## **4. Thời gian giao hàng & mức độ hài lòng**
#
# Dữ liệu ngẫu nhiên 50 đơn hàng:
#
# * Thời gian giao hàng: 1–7 ngày
# * Đánh giá khách hàng: 1–5 sao
#
# **Yêu cầu:**
# Vẽ scatter thể hiện mối liên hệ giữa thời gian giao hàng và điểm hài lòng.

# %% [markdown]
# ## **5. Phân phối trọng lượng kiện hàng**
#
# Dữ liệu 500 kiện hàng:
#
# * Trọng lượng (kg): random trong khoảng 1–50 kg nhưng tập trung nhiều ở 10–20 kg.
#
# **Yêu cầu:**
# Vẽ histogram với bins=15.

# %% [markdown]
# ## **6. Sản lượng xuất khẩu theo quốc gia**
#
# Dữ liệu:
#
# * Các nước: ['USA','China','Japan','Korea','Germany']
# * Sản lượng (tấn): [120, 160, 90, 110, 80]
#
# **Yêu cầu:**
# Vẽ bar chart cột đứng.

# %% [markdown]
# ## **7. Thời gian xử lý tại các bộ phận**
#
# Bộ phận: ['Kho', 'Đóng gói', 'Kiểm định', 'Vận chuyển']
# Thời gian xử lý (phút): [30, 45, 20, 180]
#
# **Yêu cầu:**
# Bar chart dạng ngang.

# %% [markdown]
# ## **8. Cơ cấu doanh thu theo ngành hàng**
#
# Dữ liệu:
#
# * Điện tử: 35%
# * Dệt may: 25%
# * Nông sản: 20%
# * Khác: 20%
#
# **Yêu cầu:**
# Vẽ pie chart cơ bản.

# %% [markdown]
# ## **9. Nhấn mạnh mặt hàng chủ lực**
#
# Dữ liệu giống bài 8
# **Yêu cầu:**
# Tách riêng phần “Điện tử” bằng hiệu ứng explode.

# %% [markdown]
# ## **10. Tổng hợp báo cáo quý**
#
# Dữ liệu:
#
# * Doanh thu quý: [5.2, 6.0, 6.8, 7.1] (triệu USD)
# * Chi phí vận hành: [2.1, 2.3, 2.5, 2.7]
# * Sản lượng hàng hóa: [820, 860, 900, 940]
# * Tỷ lệ giao hàng đúng hạn: [92, 94, 93, 95]
#
# **Yêu cầu:**
# Vẽ 4 biểu đồ bằng Subplots (line/bar/scatter tùy chọn) trong grid 2x2.

# %% [markdown]
# ## **11. Tốc độ thông quan**
#
# Tốc độ xử lý hồ sơ (phút):
#
# * Tuần 1–6: [45, 48, 44, 42, 43, 40]
#
# **Yêu cầu:**
# Vẽ line chart có bật grid dạng nét đứt.

# %% [markdown]
# **12. Chi phí logistics**
#
# Dữ liệu:
#
# * Tháng: Jan–Apr
# * Chi phí logistics (triệu VND): [90, 100, 95, 110]
#
# **Yêu cầu:**
# Thêm:
#
# * Title: “Chi phí logistics theo tháng”
# * Xlabel: “Tháng”
# * Ylabel: “Chi phí (triệu VND)”

# %% [markdown]
# ## **13. Lưu lượng container cảng biển**
#
# Tháng: 1–6
# Số container TEU: [800, 820, 780, 830, 860, 900]
#
# **Yêu cầu:**
# Vẽ line chart + marker size = 8.

# %% [markdown]
# ## **14. Scatter + Colormap – Giao hàng & khoảng cách**
#
# Tạo dữ liệu 100 đơn hàng:
#
# * Khoảng cách: 1–200 km
# * Thời gian giao: 1–48 giờ
# * Phí ship: 20k – 200k (dùng làm màu)
#
# **Yêu cầu:**
# Scatter plot dùng colormap 'viridis'.
