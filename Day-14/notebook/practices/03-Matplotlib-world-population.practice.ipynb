# %% [markdown]
# # Bài tập vận dụng thực hành Matplotlib

# %% [markdown]
# ## 1. Phân tích dữ liệu `World Population`

# %% [markdown]
# Từ dữ liệu này hãy làm sáng tõ các vấn đề sau:

# %% [markdown]
# ### 1.1 Top 15 quốc gia đông dân nhất năm 2022

# %% [markdown]
# ### 1.2 Phân bố dân số thế giới năm 2022 theo 6 châu lục

# %% [markdown]
# ### 1.3 Lịch sử dân số 1970–2022 của 8 nước lớn nhất thế giới (China, India, USA, Indonesia, Pakistan, Brazil, Nigeria, Bangladesh)

# %% [markdown]
# Gợi ý: Line (multi-line)

# %% [markdown]
# ### 1.4 Phân bố mật độ dân số (Density per km²) của tất cả các quốc gia (log scale)

# %% [markdown]
# Gợi ý: Histogram

# %% [markdown]
# ### 1.5 Mối quan hệ giữa Diện tích (Area) và Dân số 2022 – Ai là “người khổng lồ thưa dân”?

# %% [markdown]
# Gợi ý: Scatter

# %% [markdown]
# ### 1.6 Top 10 quốc gia có tốc độ tăng trưởng dân số cao nhất và thấp nhất 2020→2022

# %% [markdown]
# Gợi ý: Bar (two-side)

# %% [markdown]
# ### 1.7 Sự thay đổi xếp hạng dân số của Ấn Độ và Trung Quốc từ 1970 đến 2022

# %% [markdown]
# Gợi ý: Line (dual line)

# %% [markdown]
# ### 1.8 Phân bố dân số 2022 theo nhóm dân số (0-1tr, 1-10tr, 10-50tr, 50-100tr, >100tr)

# %% [markdown]
# ### 1.9 So sánh dân số châu Phi qua các năm 1970–2022 (stacked line hoặc area)
