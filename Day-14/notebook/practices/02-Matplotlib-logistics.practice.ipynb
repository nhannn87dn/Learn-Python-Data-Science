# %% [markdown]
# # Bài tập vận dụng thực hành Matplotlib

# %% [markdown]
# ## 1. Trực quan hoá dữ liệu `Logistics`

# %% [markdown]
# Tư kết quả của việc phân tích dữ liệu từ bài tập `Logistics Dataset` trong bài trước. Hãy trực quan hoá dữ liệu.
