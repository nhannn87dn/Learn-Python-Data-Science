# %% [markdown]
# ## 📊 Bài 14: Trực quan hoá dữ liệu (Data Visualization)

# %% [markdown]
# ### 1. Phân tích Tình trạng Khách hàng Thanh toán
#
# * **Mục tiêu:** Xác định tỷ lệ khách hàng đã và chưa thanh toán (*Paying Customer*).
# * **Trực quan hóa:** Sử dụng **biểu đồ tròn (Pie Chart)** để thể hiện tỷ lệ phần trăm của các trạng thái *'Yes'* và *'No'* trong cột **Paying Customer**.
# * **Giá trị:** Giúp bạn nhanh chóng nắm bắt cơ cấu doanh thu hoặc đối tượng khách hàng cốt lõi.
#
# ### 2. Phân tích Danh sách Khách hàng Cần Liên hệ
#
# * **Mục tiêu:** Xác định số lượng khách hàng **KHÔNG** muốn bị liên hệ (*Do_Not_Contact*).
# * **Trực quan hóa:**
#     * Sử dụng **biểu đồ cột (Bar Chart)** để so sánh số lượng khách hàng có trạng thái *'Yes'*/ *'Y'* và *'No'* trong cột **Do_Not_Contact**.
#     * Bạn cũng có thể tạo một biểu đồ cột gộp để xem số lượng khách hàng *'Paying Customer'* (Yes/No) trong mỗi nhóm *'Do_Not_Contact'* (Yes/No).
# * **Giá trị:** Rất quan trọng cho việc lọc danh sách gọi điện cuối cùng, tối ưu hóa nguồn lực và tuân thủ quy định.
#
# ### 3. Phân tích Phân phối Khách hàng theo Tình trạng Thanh toán và Liên hệ
#
# * **Mục tiêu:** Trực quan hóa sự phân phối của Khách hàng Trả phí và Khách hàng Không trả phí dựa trên việc họ có muốn bị liên hệ hay không.
# * **Trực quan hóa:** Sử dụng **Biểu đồ cột chồng (Stacked Bar Chart)** hoặc **Biểu đồ cột gộp (Grouped Bar Chart)**, trong đó:
#     * Trục X: **Do_Not_Contact** (No/Yes).
#     * Màu sắc: **Paying Customer** (Yes/No).
#     * Trục Y: Số lượng khách hàng.
# * **Giá trị:** Cung cấp cái nhìn sâu sắc về các nhóm khách hàng mục tiêu nhất (ví dụ: khách hàng trả phí VÀ không cấm liên hệ).
#
# ### 4. Phân tích Dữ liệu Số điện thoại bị Thiếu hoặc Không chuẩn
#
# * **Mục tiêu:** Kiểm tra chất lượng dữ liệu bằng cách xác định các bản ghi có số điện thoại bị thiếu hoặc định dạng không chuẩn (ví dụ: N/a, giá trị rỗng).
# * **Trực quan hóa:** Sử dụng một **biểu đồ cột (Bar Chart)** đơn giản để hiển thị tổng số dòng đã được làm sạch (số điện thoại hợp lệ) và số dòng đã bị loại bỏ (số điện thoại thiếu hoặc không hợp lệ).
# * **Giá trị:** Đánh giá độ tin cậy của tập dữ liệu sau quá trình làm sạch.
