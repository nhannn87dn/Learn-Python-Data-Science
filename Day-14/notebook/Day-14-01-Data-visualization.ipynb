# %% [markdown]
# ## 📊 Bài 14: Trực quan hoá dữ liệu (Data Visualization)

# %% [markdown]
# ##  1. Insight là gì ?

# %% [markdown]
# Trong **ngữ cảnh phân tích dữ liệu**, **insight** là **thông tin sâu sắc hoặc hiểu biết quan trọng rút ra từ dữ liệu**, giúp **giải thích nguyên nhân, xu hướng, hoặc cơ hội tiềm ẩn**, từ đó hỗ trợ **quyết định kinh doanh hoặc hành động cụ thể**.
#
# Nói cách khác, **insight không chỉ là dữ liệu thô hay con số**, mà là **ý nghĩa đằng sau những con số đó**.
#
# ---
#
# ### Ví dụ:
#
# Giả sử bạn có bảng dữ liệu doanh thu theo tháng:
#
# | Tháng | Doanh thu |
# | ----- | --------- |
# | Jan   | 1000      |
# | Feb   | 1200      |
# | Mar   | 800       |
# | Apr   | 1500      |
#
# * **Dữ liệu thô**: các con số doanh thu.
# * **Phân tích sơ bộ**: thấy doanh thu tháng 3 giảm so với tháng 2.
# * **Insight**: "Doanh thu giảm trong tháng 3 có thể liên quan đến việc marketing bị giảm, cần tăng quảng cáo hoặc ưu đãi trong thời gian này để tăng doanh thu."
#
# ---
#
# ### Đặc điểm của insight:
#
# 1. **Có giá trị hành động**: giúp đưa ra quyết định.
# 2. **Được rút ra từ dữ liệu**: dựa trên phân tích, trực quan hóa, hoặc so sánh.
# 3. **Có thể dự đoán hoặc giải thích**: không chỉ nói “số này lớn hay nhỏ”, mà là “tại sao và nên làm gì”.

# %% [markdown]
# ## 2.Data Visualization là gì ?

# %% [markdown]
# **Trực quan hóa dữ liệu** (Data Visualization) là quá trình **biểu diễn dữ liệu dưới dạng đồ họa** (biểu đồ, đồ thị, bản đồ…) để dễ hiểu, phát hiện xu hướng, so sánh dữ liệu và đưa ra quyết định. Thay vì nhìn hàng nghìn dòng số liệu, bạn chỉ cần vài biểu đồ là thấy ngay insight.

# %% [markdown]
# ## 3. Công cụ

# %% [markdown]
# **Hai thư viện chính:**
#
# * **Matplotlib:** Thư viện cơ bản, mạnh mẽ, tùy biến cao.
# * **Seaborn:** Xây dựng dựa trên Matplotlib, dễ dùng hơn, có giao diện đẹp và nhiều biểu đồ thống kê.

# %% [markdown]
# > Xem file tiếp theo
