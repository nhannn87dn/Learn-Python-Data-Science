# %% [markdown]
# # Bài tập về Pandas Series

# %% [markdown]
# Hãy chạy phần import thư viện trước khi làm bài

# %%
#Import thư viện
import pandas as pd
import numpy as np

# %% [markdown]
# **Bài 1**: Tạo một `Series` từ danh sách `[12, 15, 18, 20, 25]` với index là `['a','b','c','d','e']`.

# %% [markdown]
# **Bài 2**: Cho dictionary sau:
#
# ```python
# {'Math': 8.5, 'Physics': 7.8, 'Chemistry': 9.0}
# ```
#
# Hãy tạo Series tương ứng và in ra **index** và **values**.

# %%
subjects = {'Math': 8.5, 'Physics': 7.8, 'Chemistry': 9.0}
#Code tiếp ở đây

# %% [markdown]
# **Câu 3**: Cho một `series` như sau
# ```python
# s = pd.Series([10, 20, 30, 40], index=['x','y','z','t'])
# ```
#
# Lấy và in giá trị tại index `'z'`.

# %%
s = pd.Series([10, 20, 30, 40], index=['x','y','z','t'])
#Code tiếp ở đây

# %% [markdown]
# **Câu 4** Từ Series ở bài 3, lấy các giá trị tại index `['x', 't']`

# %% [markdown]
# **Câu 5** Với Series:
#
# ```python
# s = pd.Series([5, 12, 18, 7, 25])
# ```
#
# Lọc ra các giá trị **lớn hơn 10**.

# %%
s = pd.Series([5, 12, 18, 7, 25])
#Code tiếp ở đây

# %% [markdown]
# **Câu 6** Kiểm tra xem `'y'` có phải là một index trong Series ở bài 3.

# %% [markdown]
# **Câu 7**: Cho Series:
#
# ```python
# s = pd.Series([2, 4, 6, 8])
# ```
#
# Tính **squared_s = s * s**.

# %% [markdown]
# **Câu 8**: Cho Series:
#
# ```python
# s = pd.Series(['1', '2', '3', '4'])
# ```
#
# Chuyển toàn bộ thành kiểu số nguyên.

# %%
s = pd.Series(['1', '2', '3', '4'])
# Code tiếp ở đây

# %% [markdown]
# **Câu 9** Cho Series:
#
# ```python
# s = pd.Series([10, None, 30, None, 50])
# ```
#
# Tìm vị trí các phần tử **bị thiếu (NaN)**.

# %%
s = pd.Series([10, None, 30, None, 50])
# Code tiếp ở đây

# %% [markdown]
# **Câu 10** Từ Series ở bài 9, hãy thay tất cả `NaN` bằng giá trị `0`.

# %% [markdown]
# **Câu 11** Cho Series:
#
# ```python
# s = pd.Series([12, 15, 9, 20, 17])
# ```
#
# Hãy lấy: `mean`, `max`, `min`.

# %%
s = pd.Series([12, 15, 9, 20, 17])
#Code tiếp ở đây

# %% [markdown]
# **Câu 12** Cho Series:
#
# ```python
# s = pd.Series([1, 2, 2, 3, 4, 4, 4])
# ```
#
# Xác định các giá trị **unique** và **tần suất xuất hiện**.

# %%
s = pd.Series([1, 2, 2, 3, 4, 4, 4])
#Code tiếp ở đây

# %% [markdown]
# **Câu 13** Sắp xếp các giá trị trong Series sau theo thứ tự tăng dần:
#
# ```python
# s = pd.Series([50, 10, 40, 30])
# ```

# %%
s = pd.Series([50, 10, 40, 30])
#Code tiếp ở đây

# %% [markdown]
# **Câu 14** Cho Series:
#
# ```python
# s = pd.Series([100, 200, 300], index=['a','b','c'])
# ```
#
# Đổi tên index thành: `['math','phy','chem']`.

# %%
s = pd.Series([100, 200, 300], index=['a','b','c'])
#Code tiếp ở đây

# %% [markdown]
# **Câu 15** Cho hai Series:
#
# ```python
# s1 = pd.Series([1, 2, 3], index=['a','b','c'])
# s2 = pd.Series([4, 5, 6], index=['b','c','d'])
# ```
#
# Hãy cộng hai Series đó lại với nhau và quan sát kết quả.

# %%
s1 = pd.Series([1, 2, 3], index=['a','b','c'])
s2 = pd.Series([4, 5, 6], index=['b','c','d'])
#Code tiếp ở đây
