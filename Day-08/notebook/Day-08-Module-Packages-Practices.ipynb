# %% [markdown]
# # Bài tập Day 08 - Modules & Packages

# %% [markdown]
# ## 📘 Bài 1: Sử dụng Module `math`
# Viết chương trình sử dụng module `math` để:
# 1. Nhập một số từ bàn phím và in ra căn bậc hai của số đó.
# 2. Tính giai thừa của một số nguyên.
# 3. Làm tròn số π đến 4 chữ số thập phân.

# %%
import math
# Viết code của bạn ở đây

# %% [markdown]
# ## 📘 Bài 2: Nhập vào một danh sách điểm của 5 môn học (dạng float), sau đó:
#
# - In ra điểm làm tròn lên
# - In ra điểm làm tròn xuống

# %%
import math
# Viết code ở đây

# %% [markdown]
# ## 📘 Bài 3: Sử dụng Module `datetime`
# In ra:
# 1. Ngày và giờ hiện tại.
# 2. Ngày mai và hôm qua.
# 3. Đếm số ngày còn lại đến Tết Dương lịch năm sau.

# %%
from datetime import datetime, timedelta
# Viết code ở đây

# %% [markdown]
# ## 📘 Bài 4: Tính tuổi từ ngày sinh
# Nhập ngày sinh của bạn theo định dạng `YYYY-MM-DD` và tính tuổi hiện tại bằng `datetime`.

# %%
from datetime import datetime
# Viết code ở đây

# %% [markdown]
# ## 🎲 Bài 5: Sử dụng Module `random`
# 1. Sinh ra 1 số ngẫu nhiên từ 1 đến 100.
# 2. Chọn ngẫu nhiên một phần tử trong danh sách.
# 3. Xáo trộn ngẫu nhiên danh sách `[1, 2, 3, 4, 5]`.

# %%
import random
# Viết code ở đây

# %% [markdown]
# ## 🎲 Bài 6: Mô phỏng tung xúc xắc
# Sử dụng `random.randint()` để mô phỏng kết quả `10 lần` tung một con xúc xắc 6 mặt.

# %%
import random
# Viết code ở đây

# %% [markdown]
# ## 🧮 Bài 7: Kết hợp `math` và `random`
# Sinh ra 5 số thực ngẫu nhiên trong đoạn [0, 10] và in ra giá trị làm tròn xuống (`math.floor`) và làm tròn lên (`math.ceil`) của từng số.

# %%
import math, random
# Viết code ở đây

# %% [markdown]
# ## 🧩 Bài 8: Tạo Module Riêng
# Tạo một file `my_utils.py` chứa các hàm sau:
# - `add(a, b)` → trả về tổng.
# - `is_even(n)` → kiểm tra số chẵn.
#
# Sau đó import và sử dụng các hàm này trong notebook.

# %%
# from my_utils import add, is_even
# Viết code ở đây

# %% [markdown]
# ## 🧱 Bài 9: Làm việc với Package
# Tạo một **package** tên `geometry` gồm hai module:
# - `circle.py`: chứa hàm `area_circle(r)` và `circumference(r)`.
# - `rectangle.py`: chứa hàm `area_rectangle(w, h)`.
# Sau đó import package và tính diện tích, chu vi tương ứng.

# %%
# from geometry.circle import area_circle
# from geometry.rectangle import area_rectangle
# Viết code ở đây

# %% [markdown]
# ## 🧠 Bài 10: Tổng hợp — Ứng dụng nhỏ
# Viết chương trình tạo ra **5 phép toán cộng hoặc trừ ngẫu nhiên** (ví dụ: `5 + 3 = ?` hoặc `10 - 7 = ?`).
#
# * Mỗi câu hỏi sử dụng `random` để sinh hai số trong khoảng từ 1 đến 20.
# * Dùng `math` (nếu cần) để tính kết quả đúng.
# * Người dùng nhập câu trả lời cho từng câu hỏi.
# * Cuối cùng, chương trình hiển thị **số câu đúng và điểm số** của người chơi.
#
# Ví dụ minh hoạ:
#
# ```mathematica
# Câu 1: 7 + 2 = ?  → bạn nhập: 9
# Câu 2: 15 - 8 = ? → bạn nhập: 7
# ...
# Kết quả: Bạn trả lời đúng 4/5 câu!
# ```

# %%
import math, random
# Viết code ở đây

# %% [markdown]
# ========================================
#
# CHỨC MỪNG ! BẠN ĐÃ VƯỢT QUA THỬ THÁCH BÀI TẬP !
#
# ## Cách nộp bài
#
# 1. Click vào liên kết **Share** phía góc trên bên phải
# 1. Tại dòng **General access**, đổi từ **Restricted** thành **Anyone with the link**
# 1. Click vào nút **Copy Link**, lấy link đó gửi cho giáo viên.
