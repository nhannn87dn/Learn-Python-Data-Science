# %% [markdown]
# # 🐍 BÀI TẬP VỀ RANGE VÀ LOOP TRONG PYTHON
#
# Mục tiêu: Luyện tập sử dụng `for`, `while`, `range()` và kết hợp điều kiện logic.
# ---

# %% [markdown]
# ### 🧩 Bài 1: In các số từ 1 đến 10.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 2: In các số chẵn từ 2 đến 20.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 3: In các số lẻ từ 1 đến 19.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 4: In bảng cửu chương của 5.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 5: Tính tổng các số từ 1 đến 100.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 6: Tính tổng các số chẵn từ 1 đến 50.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 7: In ngược từ 10 về 1.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 8: Đếm số lượng số chia hết cho 3 từ 1–100.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 9: Tính tổng các số chia hết cho 5 hoặc 7 từ 1–200.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 10: In các số từ 1 đến 30, nhưng bỏ qua số chia hết cho 4.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 11: Với n là một số nhập bởi người dùng, hãy in ra tất cả các số lẻ nhỏ hơn n.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 12: Với n là một số nhập bởi người dùng,, tính giai thừa n! (ví dụ 5! = 1×2×3×4×5).

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 13: Viết chương trình Python in ra các ký tự trong một chuỗi được nhập từ người dùng, mỗi ký tự trên một dòng
#
# Ví dụ nhập vào `kiwi` thì in ra:
#
# ```
# k
# i
# w
# i
# ```

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 14: Đếm có bao nhiêu ký tự là chữ cái thường trong chuỗi nhập từ bàn phím.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 15: Tính tiền điện bậc thang cho nhiều khách hàng.
#
# - Nếu số kWh ≤ 50: giá 1,800đ
# - Từ 51–100: giá 2,000đ
# - Trên 100: giá 2,500đ
#
# ➤ Dùng vòng lặp nhập vào 3 tên khách hàng + số chữ điện tiêu thụ hãy tính và in kết quả tiền điện phải đóng cho từng người.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 16: Tính tổng các chữ số của một số nguyên `x` được nhập từ người dùng.
#
# Ví dụ: 123 → 1 + 2 + 3 = 6.

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 17: In ra chuỗi đảo ngược.
#
# Ví dụ: Nhập một chuỗi: "Hello world" → in ra chuỗi đảo ngược --> "dlrow olleH"

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 18:  Viết chương trình Python tính tổng các `số chẵn` từ 1 đến `n`, với `n` là một số nguyên được nhập từ người dùng

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 19: Đếm số ký tự nguyên âm (a, e, i, o, u) trong một chuỗi `str` nhập từ người dùng. (Lưu ý bao gồm cả HOA và thường)

# %%
# Viết code tại đây

# %% [markdown]
# ### 🧩 Bài 20: Viết chương trình Python kiểm tra giá trị nhập vào của người dùng. Tên thủ đô của Nhật Bản là gì ? Nếu giá trị nhập vào không phải là **'Tokyo'** thì hiển thị thông báo.
# - Câu trả lời của bạn chưa chính xác. Vui lòng nhập lại.
# - Bạn tạo input để cho người dùng nhập lại câu trả lời.

# %%
# Viết code tại đây

# %% [markdown]
# ========================================
#
# CHỨC MỪNG ! BẠN ĐÃ VƯỢT QUA THỬ THÁCH BÀI TẬP VỀ RANGE, LOOP !
#
# ## Cách nộp bài
#
# 1. Click vào liên kết **Share** phía góc trên bên phải
# 1. Tại dòng **General access**, đổi từ **Restricted** thành **Anyone with the link**
# 1. Click vào nút **Copy Link**, lấy link đó gửi cho giáo viên.
