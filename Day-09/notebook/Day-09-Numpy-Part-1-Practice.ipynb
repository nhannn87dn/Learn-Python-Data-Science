# %% [markdown]
# # **Buổi 9 – Giới thiệu NumPy**
#
# > **Mục tiêu**: Làm quen với mảng 1D, thao tác cơ bản, slicing, toán tử, thống kê.
#
# **Yêu cầu**: Dùng `numpy` → import `np`
#
# ---

# %%
import numpy as np

# %% [markdown]
# ## **Bài 1: Tạo mảng từ list**
#
# **Đề bài**: Tạo mảng `arr` từ list: `[10, 20, 30, 40, 50]`.
#
# **Yêu cầu**:
# - In mảng
# - In kiểu dữ liệu (`dtype`)
# - In số phần tử (`size`)

# %%
# Bài 1

# %% [markdown]
# ## **Bài 2: Tạo mảng với `arange` và `linspace`**
#
# **Đề bài**:
# - Tạo mảng `a` từ 0 đến 10, bước nhảy 2 → dùng `np.arange()`
# - Tạo mảng `b` có 5 phần tử từ 0 đến 1 → dùng `np.linspace()`
#
# **Yêu cầu**: In 2 mảng

# %%
# Bài 2

# %% [markdown]
# ## **Bài 3: Indexing – Truy cập phần tử**
#
# **Đề bài**: Cho mảng: `arr = np.array([100, 200, 300, 400, 500])`
#
# **Yêu cầu**:
# - Lấy phần tử đầu tiên
# - Lấy phần tử cuối cùng
# - Lấy phần tử ở vị trí thứ 3 (index = 2)

# %%
# Bài 3

# %% [markdown]
# ## **Bài 4: Slicing – Cắt mảng**
#
# **Đề bài**: Cho mảng: `arr = np.arange(10, 60, 10)` → `[10, 20, 30, 40, 50]`
#
# **Yêu cầu**:
# - Lấy từ phần tử thứ 2 đến thứ 4
# - Lấy 3 phần tử cuối
# - Đảo ngược mảng

# %%
# Bài 4

# %% [markdown]
# ## **Bài 5: Toán tử số học (vectorized)**
#
# **Đề bài**: Cho 2 mảng:
# ```python
# a = np.array([1, 2, 3, 4])
# b = np.array([5, 6, 7, 8])
# ```
#
# **Yêu cầu**:
# - Tính `a + b`, `a * b`, `b / a`
# - Tính `a` bình phương

# %%
# Bài 5

# %% [markdown]
# ## **Bài 6: Broadcasting**
#
# **Đề bài**: Cho mảng: `prices = np.array([100, 200, 300])`
#
# **Yêu cầu**:
# - Tăng giá 10%: `prices * 1.1`
# - Giảm giá 25,000: `prices - 25`
# - In kết quả (làm tròn nếu cần)

# %%
# Bài 6

# %% [markdown]
# ## **Bài 7: Hàm toán học**
#
# **Đề bài**: Cho mảng: `x = np.array([1, 4, 9, 16])`
#
# **Yêu cầu**:
# - Tính căn bậc hai
# - Tính log tự nhiên
# - Tính `sin(x)`

# %%
# Bài 7

# %% [markdown]
# ## **Bài 8: Thống kê cơ bản**
#
# **Đề bài**: Doanh thu 5 ngày: `[120, 150, 90, 200, 180]` (triệu VND)
#
# **Yêu cầu**:
# - Tổng doanh thu
# - Trung bình
# - Trung vị
# - Độ lệch chuẩn
# - Ngày có doanh thu cao nhất (dùng `argmax`)

# %%
# Bài 8

# %% [markdown]
# ## **Bài 9: Lọc dữ liệu (Boolean indexing)**
#
# **Đề bài**: Điểm học sinh: `[75, 88, 92, 65, 95, 78]`
#
# **Yêu cầu**:
# - Lọc các điểm >= 90
# - Lọc các điểm từ 70 đến 90
# - Đếm số học sinh đạt (>= 80)

# %%
# Bài 9

# %% [markdown]
# ## **Bài 10: Reshape mảng 1D (bonus)**
#
# **Đề bài**: Tạo mảng 12 phần tử: `np.arange(1, 13)`
#
# **Yêu cầu**:
# - Reshape thành `(3, 4)`
# - Reshape thành `(4, -1)` → để NumPy tự tính
# - Dùng `flatten()` để trở về 1D

# %%
# Bài 10

# %% [markdown]
# Hoàn thành !
