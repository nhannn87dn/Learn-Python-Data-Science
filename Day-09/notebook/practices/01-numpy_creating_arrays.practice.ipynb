# %% [markdown]
# # Bài tập về tạo mảng với NumPy

# %% [markdown]
# ## **Bài 1: Tạo mảng từ list và kiểm tra thông tin**

# %% [markdown]
# Cho list sau:
#
# ```python
# data = [[2, 4, 6], [1, 3, 5]]
# ```
#
# **Yêu cầu:**
#
# 1. Chuyển list trên thành NumPy array.
# 2. In ra:
#
#    * Số chiều (`ndim`)
#    * Kích thước (`shape`)
#    * Tổng số phần tử (`size`)
#    * Kiểu dữ liệu (`dtype`)

# %% [markdown]
# ## **Bài 2: Tạo các mảng đặc biệt**
#
# **Yêu cầu:**
#
# 1. Tạo một mảng 4×4 toàn số 0.
# 2. Tạo một mảng 3×3 toàn số 1.
# 3. Tạo một mảng 2×5 mà tất cả phần tử đều bằng số **7**.

# %% [markdown]
# ## **Bài 3: Tạo mảng số học**
#
# **Yêu cầu:**
#
# 1. Tạo một mảng số từ 0 đến 20 bước nhảy 2 bằng `np.arange()`.
# 2. Tạo một mảng gồm **10 số cách đều** từ 5 đến 15 bằng `np.linspace()`.

# %% [markdown]
# ## **Bài 4: Tạo ma trận đơn vị và ma trận ngẫu nhiên**
#
# **Yêu cầu:**
#
# 1. Tạo ma trận đơn vị cấp 5 (`np.eye`).
# 2. Tạo mảng ngẫu nhiên kích thước 3×3 với giá trị trong khoảng `[0,1)` bằng `np.random.random()`.

# %% [markdown]
# ## **Bài 5: Bài tổng hợp – Dashboard dữ liệu**
#
# Hãy tạo một dataset mô phỏng doanh thu theo tháng:
#
# 1. Tạo mảng gồm 12 giá trị ngẫu nhiên từ 100 đến 500 (doanh thu từng tháng).
# 2. Ép kiểu dữ liệu về `int` cho toàn bộ mảng.
# 3. In ra:
#
#    * Giá trị lớn nhất
#    * Giá trị nhỏ nhất
#    * Trung bình doanh thu
