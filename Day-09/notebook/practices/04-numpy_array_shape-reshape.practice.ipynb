# %% [markdown]
# # Bài tập về NumPy Array Shape & Reshaping

# %% [markdown]
# **Bài 1**: Tạo một mảng NumPy chứa 5 số nguyên ngẫu nhiên từ 1 đến 100. Kiểm tra và in ra hình dạng của mảng đó.

# %% [markdown]
# **Bài 2**: Tạo một mảng chứa 12 số nguyên từ 0 đến 11. Sau đó, reshape nó thành mảng có kích thước (3, 4) và in ra mảng đã thay đổi hình dạng.

# %% [markdown]
# **Bài 3**: Tạo một mảng `2 chiều (3x3)` chứa các số nguyên từ 1 đến 9. Sau đó biến mảng này thành `1 chiều` và in kết quả.
# python

# %% [markdown]
# **Bài 4**: Tạo một mảng 2 chiều (4x4) với các giá trị từ 1 đến 16.
#
# - Hãy tạo một view của mảng này.
# - Thay đổi giá trị của phần tử đầu tiên trong view và in mảng gốc để xem sự thay đổi.

# %% [markdown]
# **Bài 5**: Tạo một mảng chứa 24 phần tử từ 0 đến 23. Sử dụng reshape biến mảng thành dạng 4 hàng.
